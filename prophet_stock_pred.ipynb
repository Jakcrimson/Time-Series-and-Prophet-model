# %%
from stocker import Stocker
import quandl
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
quandl.ApiConfig.api_key = "your_key_i_suppose"

# %%
data = Stocker('ACN')
# Out:
# ACN Stocker Initialized. Data covers 2001-07-19 00:00:00 to 2018-03-27 00:00:00.

# %%
data.plot_stock()
# Out:
# Maximum Adj. Close = 164.74 on 2018-02-26 00:00:00.
# Minimum Adj. Close = 9.34 on 2001-09-27 00:00:00.
# Current Adj. Close = 148.86 on 2018-03-27 00:00:00.

# %%
model, model_data = data.create_prophet_model(days=90)
# Out:
# Predicted Price on 2018-06-25 00:00:00 = $169.61

# %%
data.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $143.35.
# Actual price on    2018-03-23 00:00:00 = $147.35.
#
# Average Absolute Error on Training Data = $1.71.
# Average Absolute Error on Testing  Data = $10.94.
#
# When the model predicted an increase, the price increased 60.93% of the time.
# When the model predicted a  decrease, the price decreased  46.94% of the time.
#
# The actual value was within the 80% confidence interval 36.00% of the time.

# %%
data.evaluate_prediction(nshares=1)
# Out:
# d:\Artificial Intelligence\STOCK_PREDICTION_OFFICIAL\stocker.py:779: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_pred_increase["pred_profit"] = prediction_profit
# You played the stock market in ACN from 2017-03-27 00:00:00 to 2018-03-27 00:00:00 with 1 shares.
#
# When the model predicted an increase, the price increased 60.93% of the time.
# When the model predicted a  decrease, the price decreased  46.94% of the time.
#
# The total profit using the Prophet model = $27.94.
# The Buy and Hold strategy profit =         $30.32.
#
# Thanks for playing the stock market!
